# %%
import pandas as pd
import os

# %% [markdown]
# # Import Data and Analyse

# %%
ICE_PATH = 'data/ICE_SPICE.csv'

df = pd.read_csv(ICE_PATH, skiprows=1)
df.head(5)
# Out:
#                               Unique ID       Material  \
# 0  52bdfeb3-979f-4fcd-b4eb-6ffbda643c52  AggregateSand
# 1  c47ba144-190c-4ed7-84c1-423159f8af34  AggregateSand
# 2  238416cd-fce6-47b5-9c5a-4146d4067406  AggregateSand
# 3  64214af1-a2d1-4b7b-acf3-137de42de2b6  AggregateSand
# 4  2d8e1110-577f-4b24-9276-6a0b9140036a  AggregateSand
#
#                                        Sub-material  Placeholder  \
# 0         AggregateSand, General aggregate and sand          NaN
# 1         AggregateSand, General aggregate and sand          NaN
# 2           AggregateSand, Land won gravel and sand          NaN
# 3          AggregateSand, Marine sand and aggregate          NaN
# 4  AggregateSand, Recycled aggregate, no heat treat          NaN
#
#                                          ICE DB Name  \
# 0  Aggregates and sand, general UK, mixture of la...
# 1  Aggregates and sand, general, virgin mixture o...
# 2  Aggregates and sand, from virgin land won reso...
# ...

# %%
df['Material'].unique()
# Out:
# array(['AggregateSand', 'aluminium', 'Aluminium', 'Asphalt', 'Bitumen',
#        'Cement', 'Clay', 'Concrete', 'Glass', 'glass', 'Steel', 'Timber',
#        nan], dtype=object)

# %%
for i in df.columns:
    print(i)
# Out:
# Unique ID
# Material
# Sub-material
# Placeholder
# ICE DB Name
# Comments
# Boundaries
# Module D
# Wider lifecycle notes
# Quantity of declared unit
# Units of declared unit
# Weight per declared unit - kg
# Density of material - kg per m3
# Density range - low - kg per m3
# Density Range - high - kg per m3
# Carbon sequestration included?
# Carbon Storage Amount (Kg CO2 per unit)
# Carbon Storage Notes
# Embodied Carbon (kg CO2e per declared unit)
# Embodied Carbon per kg (kg CO2e per kg)
# Depletion potential of the stratospheric ozone layer. ODP kg CFC 11
# Acidification potential of soil and water. AP kg SO2 equiv
# Eutrophication potential. EP kg (PO4)3-
# Formation potential of tropospheric ozone. POCP kg Ethene
# Abiotic depletion potential (ADP-elements) for non-fossil resources kg Sb equiv
# Abiotic depletion potential (ADP-fossil fuels) for fossil resources MJ. net calorific
# value
# ...

# %%
# create df with only the columns we want
df_basic = df[['Material', 'Sub-material', 'Units of declared unit', 'Embodied Carbon (kg CO2e per declared unit)', 'Average Embodied Carbon - kg CO2e per kg' ]]
df_basic
# Out:
#           Material                                      Sub-material  \
# 0    AggregateSand         AggregateSand, General aggregate and sand
# 1    AggregateSand         AggregateSand, General aggregate and sand
# 2    AggregateSand           AggregateSand, Land won gravel and sand
# 3    AggregateSand          AggregateSand, Marine sand and aggregate
# 4    AggregateSand  AggregateSand, Recycled aggregate, no heat treat
# ..             ...                                               ...
# 529         Timber                               Timber, Wood I-Beam
# 530         Timber                    Timber, Wood-plastic composite
# 531            NaN                                               NaN
# 532            NaN                                               NaN
# 533            NaN                                               NaN
#
#     Units of declared unit  Embodied Carbon (kg CO2e per declared unit)  \
# ...
