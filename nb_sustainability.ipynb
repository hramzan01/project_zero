# %%
import pandas as pd
import numpy as np

# %%
df_sust = pd.read_excel('data_xls_sustainability.xlsx',usecols=['Region','City','GFA (m²)','Project','Name','Rating System','Level','Status'])
df_sust = df_sust[df_sust['Name'] != '-']
df_sust.dropna(subset=['Name'], inplace=True)
df_sust
# Out:
#        Region               City     GFA (m²)   Project  \
# 0      Europe            Vilnius        19200  13045-NB
# 1     America            Toronto  134995.2707  11370-00
# 2   Australia             Sydney       306466  11360-00
# 9          UK             London        97000  11010-00
# 11         UK             London        35394  10450-00
# ..        ...                ...          ...       ...
# 82         UK             London        38400       NaN
# 83     Canada            Toronto        20000      6070
# 84     Europe              Paris      Missing     10550
# 85     Europe  Paris\nLa Défense      Missing     13150
# 86     Europe               Lens      Missing     10620
#
#                                                  Name           Rating System  \
# 0                               14A Konstitucijos Ave                  BREEAM
# 1                               30 Bay Street Toronto                    LEED
# ...
