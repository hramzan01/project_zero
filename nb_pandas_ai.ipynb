# %% [markdown]
# # Data Insights with Pandas AI 🐼

# %%
from pandasai import SmartDataframe
import pandas as pd
from pandasai.llm import OpenAI
llm = OpenAI(api_token="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")
import ipywidgets as widgets
# %time
# Out:
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 7.63 µs

# %%
df = pd.read_csv('data_city_ksa.csv')
#df.columns = ['zone', 'parcel', 'precinct', 'plot', 'sub_plot', 'building', 'riverside', 'phase', 'asset', 'type', 'area', 'level', 'bua', 'gfa', 'gla', 'parking', 'employee', 'residents', 'visitor', 'units']
#df = df.applymap(lambda x: x.lower() if isinstance(x, str) else x)
df['PRECINCT'].unique()
# Out:
# array(['STADIUM PRECINCT', 'WEST CLIFF PRECINCT', 'E-GAMING PRECINCT',
#        'MID CITY PRECINCT', 'EAST CLIFF PRECINCT',
#        'PERFORMING ARTS PRECINCT', 'CITY NORTH PRECINCT 01',
#        'CITY NORTH PRECINCT 03', 'CITY NORTH PRECINCT 04',
#        'CITY NORTH PRECINCT 02', 'CITY NORTH PRECINCT 05',
#        'EAST WADI PRECINCT', 'NORTH CLIFF PRECINCT',
#        'SOUTH CLIFF PRECINCT'], dtype=object)

# %%
data = SmartDataframe(df, config={'llm': llm})

# %% [markdown]
# ### Speak to the data 🗣️

# %%
data.chat('plot the sum of areas per asset')

# %%
data.chat('plot the distribution of assets by area in E-GAMING PRECINCT ')

# %%
data.chat('give me a pie chart of the sum of areas per precinct')

# %%
data.chat('plot heatmap of different areas by asset')

# %%
data.chat('can you redo the table so all the area values are appended with a m2 at the end')
